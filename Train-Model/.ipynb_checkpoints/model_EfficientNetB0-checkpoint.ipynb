# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNEL = 3
EPOCH = 50
n_classes = 7

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
            "../PlantVillage",
            shuffle = True,
            image_size = (IMAGE_SIZE, IMAGE_SIZE),
            batch_size = BATCH_SIZE,
            color_mode='rgb'
        )
# Out:
# Found 4438 files belonging to 7 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Apple__Black__Rot',
#  'Apple__Healthy',
#  'Apple__Scab',
#  'Cedar__Apple__Rust',
#  'Potato___Early_blight',
#  'Potato___Late_blight',
#  'Potato___healthy']

# %%
len(dataset)
# Out:
# 139

# %%
plt.figure(figsize=(10, 10))
for image_batch, label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3, 4, i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(class_names[label_batch[i]])
        plt.axis("off")

# %%
# 80% => Training
# 20% => 10% validation, 10% testing

# %%
train_size = 0.8
len(dataset) * train_size
# Out:
# 111.2

# %%
train_ds = dataset.take(54) #raa[:54]
len(train_ds)
# Out:
# 54

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 85

# %%
val_size = 0.1
len(dataset) * val_size
# Out:
# 13.9

# %%
val_ds = test_ds.take(6)
len(val_ds)
# Out:
# 6

# %%
test_ds = test_ds.skip(6)
len(test_ds)
# Out:
# 79

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
        ds_size = len(ds)

        if shuffle:
            ds = ds.shuffle(shuffle_size, seed=12)
    
        train_size = int(train_split * ds_size)
        val_size = int(val_split * ds_size)

        train_ds = ds.take(train_size)
        val_ds = ds.skip(train_size).take(val_size)
        test_ds = ds.skip(train_size).skip(val_size)
    
        return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 111

# %%
len(val_ds)
# Out:
# 13

# %%
len(test_ds)
# Out:
# 15

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1.0/255)
])

# %%
# Data Augmentation -> If image is flip/rotate
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizonatal_and_vertical"),
    layers.RandomRotation(0.2)
])

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam

base_model = EfficientNetB0(
    weights='imagenet',
    include_top=False,
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3)
)

base_model.trainable = True
for layer in base_model.layers[:-50]:
    layer.trainable = False

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(512, activation='relu')(x)
x = Dropout(0.4)(x)
output = Dense(N_CLASSES, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)          │ (None, 8, 8, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 4,214,442 (16.08 MB)
#  Trainable params: 164,871 (644.03 KB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=6,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "../Store-Model/model_efficientnetb0.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=3, 
    min_lr=1e-6
)

history = model.fit(
    train_ds,
    epochs=EPOCH,
    validation_data=val_ds,
    callbacks=[early_stop, checkpoint, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6994 - loss: 0.9271
# Epoch 1: val_accuracy improved from -inf to 0.97837, saving model to ../Store-Model/model_efficientnetb0.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 196s 2s/step - accuracy: 0.7006 - loss: 0.9235 - val_accuracy: 0.9784 - val_loss: 0.0916
# Epoch 2/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9387 - loss: 0.1796
# Epoch 2: val_accuracy improved from 0.97837 to 0.99279, saving model to ../Store-Model/model_efficientnetb0.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 162s 1s/step - accuracy: 0.9387 - loss: 0.1795 - val_accuracy: 0.9928 - val_loss: 0.0464
# Epoch 3/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9455 - loss: 0.1416
# Epoch 3: val_accuracy did not improve from 0.99279
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 163s 1s/step - accuracy: 0.9456 - loss: 0.1415 - val_accuracy: 0.9904 - val_loss: 0.0326
# Epoch 4/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9653 - loss: 0.0959
# Epoch 4: val_accuracy improved from 0.99279 to 0.99519, saving model to ../Store-Model/model_efficientnetb0.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 159s 1s/step - accuracy: 0.9653 - loss: 0.0959 - val_accuracy: 0.9952 - val_loss: 0.0226
# Epoch 5/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9624 - loss: 0.1082
# Epoch 5: val_accuracy improved from 0.99519 to 0.99760, saving model to ../Store-Model/model_efficientnetb0.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9625 - loss: 0.1080 - val_accuracy: 0.9976 - val_loss: 0.0170
# Epoch 6/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9815 - loss: 0.0642
# Epoch 6: val_accuracy did not improve from 0.99760
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 170s 2s/step - accuracy: 0.9815 - loss: 0.0642 - val_accuracy: 0.9976 - val_loss: 0.0139
# Epoch 7/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9794 - loss: 0.0680
# Epoch 7: val_accuracy did not improve from 0.99760
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9794 - loss: 0.0680 - val_accuracy: 0.9976 - val_loss: 0.0131
# Epoch 8/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9729 - loss: 0.0743
# Epoch 8: val_accuracy did not improve from 0.99760
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 153s 1s/step - accuracy: 0.9729 - loss: 0.0742 - val_accuracy: 0.9952 - val_loss: 0.0183
# Epoch 9/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9821 - loss: 0.0522
# Epoch 9: val_accuracy improved from 0.99760 to 1.00000, saving model to ../Store-Model/model_efficientnetb0.keras
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.9821 - loss: 0.0522 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 10/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9790 - loss: 0.0560
# Epoch 10: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9790 - loss: 0.0560 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 11/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9847 - loss: 0.0464
# Epoch 11: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 160s 1s/step - accuracy: 0.9847 - loss: 0.0464 - val_accuracy: 0.9952 - val_loss: 0.0087
# Epoch 12/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9816 - loss: 0.0551
# Epoch 12: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9816 - loss: 0.0551 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 13/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9842 - loss: 0.0474
# Epoch 13: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9842 - loss: 0.0475 - val_accuracy: 0.9928 - val_loss: 0.0243
# Epoch 14/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9859 - loss: 0.0397
# Epoch 14: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9859 - loss: 0.0398 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 15/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9844 - loss: 0.0500
# Epoch 15: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 150s 1s/step - accuracy: 0.9844 - loss: 0.0499 - val_accuracy: 0.9976 - val_loss: 0.0090
# Epoch 16/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9858 - loss: 0.0364
# Epoch 16: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.9858 - loss: 0.0364 - val_accuracy: 0.9976 - val_loss: 0.0059
# Epoch 17/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9891 - loss: 0.0317
# Epoch 17: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.9891 - loss: 0.0317 - val_accuracy: 0.9976 - val_loss: 0.0077
# Epoch 18/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9870 - loss: 0.0340
# Epoch 18: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 152s 1s/step - accuracy: 0.9870 - loss: 0.0340 - val_accuracy: 0.9976 - val_loss: 0.0075
# Epoch 19/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9862 - loss: 0.0370
# Epoch 19: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 155s 1s/step - accuracy: 0.9862 - loss: 0.0370 - val_accuracy: 0.9952 - val_loss: 0.0087
# Epoch 20/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9855 - loss: 0.0324
# Epoch 20: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9855 - loss: 0.0324 - val_accuracy: 0.9952 - val_loss: 0.0080
# Epoch 21/30
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9885 - loss: 0.0361
# Epoch 21: val_accuracy did not improve from 1.00000
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 156s 1s/step - accuracy: 0.9885 - loss: 0.0361 - val_accuracy: 0.9952 - val_loss: 0.0082

# %%
scores = model.evaluate(test_ds)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 1.0000 - loss: 0.0040

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt

y_true = np.concatenate([y for x, y in val_ds], axis=0)
y_pred = model.predict(val_ds)
y_pred_classes = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_true, y_pred_classes)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(xticks_rotation=45, cmap="Blues")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step

# %%
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', 
            xticklabels=class_names,
            yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Heatmap Confusion Matrix - EfficientNetB0")
plt.show()

# %%
scores
# Out:
# [0.0051264152862131596, 1.0]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 30, 'steps': 111}

# %%
history.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(1, len(acc) + 1) 

plt.figure(figsize=(8, 8))

plt.subplot(1, 2, 1)
plt.plot(epochs, acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %%
import numpy as np

# Take one batch from the test dataset
for image_batch, label_batch in test_ds.take(1):
    # Get the first image and label in the batch
    first_image = image_batch[0].numpy().astype('uint8')
    first_label = label_batch[0].numpy()

    # Display the image
    print("First image to predict")
    plt.imshow(first_image)
    plt.axis('off')  # hides axis
    plt.show()

    # Print the actual label
    print("Actual Label : ", class_names[first_label])
    
    # Predict the label for the entire batch
    batch_prediction = model.predict(image_batch)
    
    # Get the predicted class of the first image
    predicted_class = np.argmax(batch_prediction[0])
    print("Predicted Label : ", class_names[predicted_class])
# Out:
# First image to predict
# Actual Label :  Potato___healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Predicted Label :  Potato___healthy

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(img.numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array, verbose=0)
    
    predicted_index = np.argmax(predictions[0])
    predicted_class = class_names[predicted_index]
    
    confidence = round(100 * np.max(predictions[0]), 2)
    
    return predicted_class, confidence

# %%
plt.figure(figsize=(12, 12))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype('uint8'))

        predicted_class, confidence = predict(model, images[i])
        actual_class = class_names[labels[i].numpy()]

        plt.title(f"Actual: {actual_class}\nPredicted: {predicted_class}\nConfidence: {confidence}%", fontsize=8)
        plt.axis("off")
        
plt.tight_layout()
plt.show()
